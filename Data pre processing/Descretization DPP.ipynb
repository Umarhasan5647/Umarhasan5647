# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r"C:\Users\ali umar hasan\Desktop\iris\iris.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Descretizing the values of the dataframe..

# %%
# using round of funciton on the particular data frames..
df['Sepal.Length']=round(df['Sepal.Length'])
df['Sepal.Width']=round(df['Sepal.Width'])
df['Petal.Width']=round(df['Petal.Width'])
df['Petal.Length']=round(df['Petal.Length'])

# %%
df.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species  \
# 0           1           5.0          4.0           1.0          0.0  setosa
# 1           2           5.0          3.0           1.0          0.0  setosa
# 2           3           5.0          3.0           1.0          0.0  setosa
# 3           4           5.0          3.0           2.0          0.0  setosa
# 4           5           5.0          4.0           1.0          0.0  setosa
#
#    Sepal.width
# 0          4.0
# 1          3.0
# 2          3.0
# 3          3.0
# 4          4.0

# %%
df = df.drop("Sepal.width",axis =1)

# %%
df.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.0          4.0           1.0          0.0  setosa
# 1           2           5.0          3.0           1.0          0.0  setosa
# 2           3           5.0          3.0           1.0          0.0  setosa
# 3           4           5.0          3.0           2.0          0.0  setosa
# 4           5           5.0          4.0           1.0          0.0  setosa
